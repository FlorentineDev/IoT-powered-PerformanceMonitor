# %%
from confluent_kafka import Producer
import json
import time
import csv
import json
import os, shutil

# %%
def find_rename_csv_file(directory):
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory '{directory}' does not exist.")
        return None

    # Traverse through the directory and its subdirectories
    for root, dirs, files in os.walk(directory):
        for file in files:
            # Check if the file is a CSV file
            if file.endswith('.csv'):
                new_name = os.path.join(root,file.split(".")[0] +"__"+ root.split("\\")[-1] +".csv")
                os.rename(os.path.join(root, file), new_name)
                return new_name

    print(f"No CSV files found in '{directory}' or its subdirectories.")
    return None

# %%
def move_file(source_file_path, destination_folder):
    # Check if the source file exists
    if not os.path.exists(source_file_path):
        print(f"Source file '{source_file_path}' does not exist.")
        return
    
    # Check if the destination folder exists, if not, create it
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    
    # Extract the filename from the source file path
    file_name = os.path.basename(source_file_path)
    
    # Move the file to the destination folder
    destination_path = os.path.join(destination_folder, file_name)
    shutil.move(source_file_path, destination_path)
    print(f"Moved '{file_name}' to '{destination_folder}'.")
    return destination_path

# %%
def csv_to_json(csv_file, json_file):
    # Open the CSV file and load data into a Python dictionary
    with open(csv_file, 'r') as file:
        csv_data = csv.DictReader(file)
        data = [row for row in csv_data]

    # Write the Python dictionary into a JSON file
    with open(json_file, 'w') as jsonfile:
        jsonfile.write(json.dumps(data))

    return json.dumps(data)

# %%
class InvoiceProducer:
    def __init__(self):
        self.topic = "xxxx"
        self.conf = {'bootstrap.servers': 'xxxx',
                     'security.protocol': 'xxxx',
                     'sasl.mechanism': 'xxxx',
                     'sasl.username': 'xxxx',
                     'sasl.password': 'xxxx',
                     'client.id': "xxxx"}
        

    def delivery_callback(self, err, msg):
        if err:
            print('ERROR: Message failed delivery: {}'.format(err))
        else:
            key = msg.key().decode('utf-8')

    def produce_invoices(self, producer,csv_file_path):

        timestamp_ms = int(time.time() * 1000)
        json_data=csv_to_json(csv_file_path,"myjson.json")
        producer.produce(self.topic, key=str(1), timestamp=timestamp_ms ,value=json_data, callback=self.delivery_callback)
        print(f"File: {csv_file_path} --> imported")
        

    def start(self, csv_file_path):
        kafka_producer = Producer(self.conf)
        self.produce_invoices(kafka_producer,csv_file_path)
        kafka_producer.flush()

# %%
if __name__ == "__main__":

    directory_path = 'C:\PerfLogs\Admin\MyLogger' # folder where csv logs are produced
    destination_folder = 'C:\\PerfLogs\\Admin\\tmp' # folder where csv files are moved definitely
    destination_folder_working = 'C:\\PerfLogs\\Admin\\working' # folder where csv files are moved temporarily
    invoice_producer = InvoiceProducer()
    
    while(True):
        try:
            csv_file_path = find_rename_csv_file(directory_path)
            if csv_file_path:
                wrkpath = move_file(csv_file_path, destination_folder_working)
                invoice_producer.start(wrkpath)
                move_file(wrkpath, destination_folder)
        except:
                print("waiting 1 minute")
                time.sleep(60)

        
        time.sleep(5)
# Out:
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000297.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000297.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000297.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000298.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000298.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000298.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000299.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000299.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000299.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000300.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000300.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000300.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000301.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000301.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000301.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000302.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000302.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000302.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000303.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000303.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000303.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000304.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000304.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000304.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000305.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000305.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000305.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000306.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000306.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000306.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000307.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000307.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000307.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000308.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000308.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000308.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000309.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000309.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000309.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000310.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000310.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000310.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000311.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000311.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000311.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000312.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000312.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000312.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000313.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000313.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000313.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000314.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000314.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000314.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000315.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000315.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000315.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000316.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000316.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000316.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000317.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000317.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000317.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000318.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000318.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000318.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000319.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000319.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000319.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000320.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000320.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000320.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000321.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000321.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000321.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000322.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000322.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000322.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000323.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000323.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000323.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000324.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000324.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000324.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000325.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000325.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000325.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000326.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000326.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000326.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000327.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000327.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000327.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000328.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000328.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000328.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000329.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000329.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000329.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000330.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000330.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000330.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000331.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000331.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000331.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000332.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000332.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000332.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000333.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000333.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000333.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000334.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000334.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000334.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000335.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000335.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000335.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000336.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000336.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000336.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000337.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000337.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000337.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000338.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000338.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000338.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000339.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000339.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000339.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000340.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000340.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000340.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000341.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000341.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000341.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000342.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000342.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000342.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000343.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000343.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000343.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000344.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000344.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000344.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000345.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000345.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000345.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000346.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000346.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000346.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000347.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000347.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000347.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000348.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000348.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000348.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000349.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000349.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000349.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000350.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000350.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000350.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000351.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000351.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000351.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000352.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000352.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000352.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000353.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000353.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000353.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000354.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000354.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000354.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000355.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000355.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000355.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000356.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000356.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000356.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000357.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000357.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000357.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000358.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000358.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000358.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000359.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000359.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000359.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000360.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000360.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000360.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000361.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000361.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000361.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000362.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000362.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000362.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000363.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000363.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000363.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000364.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000364.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000364.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000365.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000365.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000365.csv' to 'C:\PerfLogs\Admin\tmp'.
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000366.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000366.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000366.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000367.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000367.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000367.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000368.csv' to 'C:\PerfLogs\Admin\working'.
# File: C:\PerfLogs\Admin\working\SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000368.csv --> imported
# Moved 'SUPERPORTATILE_Performance_Counter__SUPERPORTATILE_20240323-000368.csv' to 'C:\PerfLogs\Admin\tmp'.
# waiting 1 minute
